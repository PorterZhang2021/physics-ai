# %% [markdown]
# claude --resume b6afa7d9-430b-4b52-9f0f-b5cef4c1a7a2
# # Review: Vectors — What Even Are They?
#
# **Source:** 3Blue1Brown, *Essence of Linear Algebra*, Episode 1
#
# ---
#
# Fill in each section in your own words. No need to copy the video — explain it as if you're teaching someone else.

# %% [markdown]
# ## 1. Three Ways to Think About a Vector
#
# The video presents three perspectives: the **physics** view, the **CS** view, and the **math** view.
#
# In your own words, what is each one?
#
# - **Physics:** A vector is an arrow with a length and direction, which we can use to represent movement (e.g. displacement 位移, velocity 速度, force 力). The arrow can be placed anywhere in space — only its length and direction matter.
# - **CS (Computer Science):**
# - **Math:**
#
# Which perspective feels most natural to you right now, and why?

# %% [markdown]
# ## 2. Vector Addition
#
# Describe vector addition in your own words — geometrically (what does it look like?) and numerically (how do you compute it?).
#
# - **Geometrically:**
# - **Numerically:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define two vectors and compute their sum
# (fill in values and complete the plot)

v1 = np.array([?, ?])
v2 = np.array([?, ?])
v_sum = ?

# %% [markdown]
# ## 3. Scalar Multiplication
#
# What does multiplying a vector by a scalar do — geometrically?
#
# - **When scalar > 1:**
# - **When 0 < scalar < 1:**
# - **When scalar < 0:**

# %%
# Scale a vector by different scalars and observe the result

v = np.array([?, ?])

# Try scalar = 2, 0.5, -1

# %% [markdown]
# ## 4. The Key Insight
#
# What is the one thing from this video that you want to remember?
#
# > *Write it here in one sentence.*

# %% [markdown]
# ## 5. Open Question
#
# Is there anything from the video that you're **not sure about**, or that felt unclear?
#
# > *Write it here — we'll work through it together.*
